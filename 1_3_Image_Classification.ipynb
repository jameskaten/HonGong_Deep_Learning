# %% [markdown]
# # 1_3 Image Classification
# > LetNet Model
# - Sigmoid function
# - ReLU function

# %%
# !python3 -m pip install numpy
# !python3 -m pip install matplotlib
# !python3 -m pip install scipy
# Out:
# Requirement already satisfied: numpy in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (2.4.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: matplotlib in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (3.10.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from matplotlib) (2.4.0)
# Requirement already satisfied: packaging>=20.0 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Collecting scipy
#   Downloading scipy-1.16.3-cp311-cp311-macosx_14_0_arm64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2.6,>=1.25.2 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from scipy) (2.4.0)
# Downloading scipy-1.16.3-cp311-cp311-macosx_14_0_arm64.whl (20.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 37.8 MB/s eta 0:00:0000:0100:01
# Installing collected packages: scipy
# Successfully installed scipy-1.16.3
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.special import expit

x = np.arange(-10, 10, 0.2)

fig, axs = plt.subplots(1, 2, figsize=(12, 4))
axs[0].plot(x, expit(x))    # Sigmoid function in Scipy
axs[0].set_title('sigmoid function')
axs[0].set_xlabel('x')
axs[0].set_ylabel('f(x)')
axs[1].plot(x, x.clip(0))   # ReLU function
axs[1].set_title('relu function')
axs[1].set_xlabel('x')
axs[1].set_ylabel('f(x)')
plt.show()

# %%
# !python3 -m pip install keras
# !python3 -m pip install tensorflow
# Out:
# Requirement already satisfied: keras in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (3.13.0)
# Requirement already satisfied: absl-py in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras) (2.3.1)
# Requirement already satisfied: numpy in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras) (2.4.0)
# Requirement already satisfied: rich in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras) (14.2.0)
# Requirement already satisfied: namex in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras) (0.1.0)
# Requirement already satisfied: h5py in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras) (3.15.1)
# Requirement already satisfied: optree in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras) (0.18.0)
# Requirement already satisfied: ml-dtypes in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras) (0.5.4)
# Requirement already satisfied: packaging in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras) (25.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from optree->keras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from rich->keras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from rich->keras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras) (0.1.2)
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Collecting tensorflow
#   Downloading tensorflow-2.20.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (4.5 kB)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (2.3.1)
# Collecting astunparse>=1.6.0 (from tensorflow)
#   Using cached astunparse-1.6.3-py2.py3-none-any.whl.metadata (4.4 kB)
# Collecting flatbuffers>=24.3.25 (from tensorflow)
#   Using cached flatbuffers-25.12.19-py2.py3-none-any.whl.metadata (1.0 kB)
# Collecting gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 (from tensorflow)
#   Using cached gast-0.7.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting google_pasta>=0.1.1 (from tensorflow)
#   Using cached google_pasta-0.2.0-py3-none-any.whl.metadata (814 bytes)
# Collecting libclang>=13.0.0 (from tensorflow)
#   Using cached libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl.metadata (5.2 kB)
# Collecting opt_einsum>=2.3.2 (from tensorflow)
#   Using cached opt_einsum-3.4.0-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (25.0)
# Collecting protobuf>=5.28.0 (from tensorflow)
#   Using cached protobuf-6.33.2-cp39-abi3-macosx_10_9_universal2.whl.metadata (593 bytes)
# Collecting requests<3,>=2.21.0 (from tensorflow)
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: setuptools in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: six>=1.12.0 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (1.17.0)
# Collecting termcolor>=1.1.0 (from tensorflow)
#   Downloading termcolor-3.3.0-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: typing_extensions>=3.6.6 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (4.15.0)
# Collecting wrapt>=1.11.0 (from tensorflow)
#   Downloading wrapt-2.0.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (9.0 kB)
# Collecting grpcio<2.0,>=1.24.3 (from tensorflow)
#   Downloading grpcio-1.76.0-cp311-cp311-macosx_11_0_universal2.whl.metadata (3.7 kB)
# Collecting tensorboard~=2.20.0 (from tensorflow)
#   Using cached tensorboard-2.20.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: keras>=3.10.0 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: numpy>=1.26.0 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: h5py>=3.11.0 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorflow) (0.5.4)
# Collecting wheel<1.0,>=0.23.0 (from astunparse>=1.6.0->tensorflow)
#   Using cached wheel-0.45.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: rich in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow) (14.2.0)
# Requirement already satisfied: namex in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from keras>=3.10.0->tensorflow) (0.18.0)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.21.0->tensorflow)
#   Downloading charset_normalizer-3.4.4-cp311-cp311-macosx_10_9_universal2.whl.metadata (37 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.21.0->tensorflow)
#   Using cached idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests<3,>=2.21.0->tensorflow)
#   Using cached urllib3-2.6.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.21.0->tensorflow)
#   Using cached certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting markdown>=2.6.8 (from tensorboard~=2.20.0->tensorflow)
#   Using cached markdown-3.10-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: pillow in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from tensorboard~=2.20.0->tensorflow) (12.0.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard~=2.20.0->tensorflow)
#   Using cached tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard~=2.20.0->tensorflow)
#   Using cached werkzeug-3.1.4-py3-none-any.whl.metadata (4.0 kB)
# Collecting markupsafe>=2.1.1 (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow)
#   Downloading markupsafe-3.0.3-cp311-cp311-macosx_11_0_arm64.whl.metadata (2.7 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from rich->keras>=3.10.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from rich->keras>=3.10.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)
# Downloading tensorflow-2.20.0-cp311-cp311-macosx_12_0_arm64.whl (200.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.5/200.5 MB 40.4 MB/s eta 0:00:0000:0100:01
# Using cached astunparse-1.6.3-py2.py3-none-any.whl (12 kB)
# Using cached flatbuffers-25.12.19-py2.py3-none-any.whl (26 kB)
# Using cached gast-0.7.0-py3-none-any.whl (22 kB)
# Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Downloading grpcio-1.76.0-cp311-cp311-macosx_11_0_universal2.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 49.3 MB/s eta 0:00:00a 0:00:01
# Using cached libclang-18.1.1-1-py2.py3-none-macosx_11_0_arm64.whl (25.8 MB)
# Using cached opt_einsum-3.4.0-py3-none-any.whl (71 kB)
# Using cached protobuf-6.33.2-cp39-abi3-macosx_10_9_universal2.whl (427 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached tensorboard-2.20.0-py3-none-any.whl (5.5 MB)
# Downloading termcolor-3.3.0-py3-none-any.whl (7.7 kB)
# Downloading wrapt-2.0.1-cp311-cp311-macosx_11_0_arm64.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.6/61.6 kB 7.9 MB/s eta 0:00:00
# Using cached certifi-2025.11.12-py3-none-any.whl (159 kB)
# Downloading charset_normalizer-3.4.4-cp311-cp311-macosx_10_9_universal2.whl (206 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.0/207.0 kB 24.4 MB/s eta 0:00:00
# Using cached idna-3.11-py3-none-any.whl (71 kB)
# Using cached markdown-3.10-py3-none-any.whl (107 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Using cached urllib3-2.6.2-py3-none-any.whl (131 kB)
# Using cached werkzeug-3.1.4-py3-none-any.whl (224 kB)
# Using cached wheel-0.45.1-py3-none-any.whl (72 kB)
# Downloading markupsafe-3.0.3-cp311-cp311-macosx_11_0_arm64.whl (12 kB)
# Installing collected packages: libclang, flatbuffers, wrapt, wheel, urllib3, termcolor, tensorboard-data-server, protobuf, opt_einsum, markupsafe, markdown, idna, grpcio, google_pasta, gast, charset_normalizer, certifi, werkzeug, requests, astunparse, tensorboard, tensorflow
# Successfully installed astunparse-1.6.3 certifi-2025.11.12 charset_normalizer-3.4.4 flatbuffers-25.12.19 gast-0.7.0 google_pasta-0.2.0 grpcio-1.76.0 idna-3.11 libclang-18.1.1 markdown-3.10 markupsafe-3.0.3 opt_einsum-3.4.0 protobuf-6.33.2 requests-2.32.5 tensorboard-2.20.0 tensorboard-data-server-0.7.2 tensorflow-2.20.0 termcolor-3.3.0 urllib3-2.6.2 werkzeug-3.1.4 wheel-0.45.1 wrapt-2.0.1
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# LeNet model
import keras
from keras import layers

lenet5 = keras.Sequential()
lenet5.add(layers.Input(shape=(28,28,1)))
lenet5.add(layers.Conv2D(filters=6, kernel_size=5, activation='sigmoid', padding='same'))
lenet5.add(layers.AveragePooling2D(pool_size=2))
lenet5.add(layers.Conv2D(filters=16, kernel_size=5, activation='sigmoid'))
lenet5.add(layers.AveragePooling2D(pool_size=2))
lenet5.add(layers.Flatten())
lenet5.add(layers.Dense(120, activation='sigmoid'))
lenet5.add(layers.Dense(84, activation='sigmoid'))
lenet5.add(layers.Dense(10, activation='softmax'))      # softmax: multi-classification

# %%
lenet5.summary()
# Out:
# Model: "sequential_6"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)               │ (None, 28, 28, 6)      │           156 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_4             │ (None, 14, 14, 6)      │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 10, 10, 16)     │         2,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d_5             │ (None, 5, 5, 16)       │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 400)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 120)            │        48,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 84)             │        10,164 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 10)             │           850 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 61,706 (241.04 KB)
#  Trainable params: 61,706 (241.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Train LeNet

# %%
(train_input, train_target), (test_input, test_target) = keras.datasets.fashion_mnist.load_data()

# %%
print(train_target)
# Out:
# [9 0 0 ... 3 0 5]

# %%
print(train_input.shape, train_target.shape)
# Out:
# (60000, 28, 28) (60000,)

# %%
import matplotlib.pyplot as plot

fig, axs = plt.subplots(1, 10, figsize=(10, 10))
for i in range(10):
    axs[i].imshow(train_input[i], cmap='gray_r')
    axs[i].axis('off')
plt.show()

# %%
train_input = train_input.reshape(-1, 28, 28, 1) / 255.0

# %%
# !python3 -m pip install scikit-learn
# !python3 -m pip install keras
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp311-cp311-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from scikit-learn) (2.4.0)
# Requirement already satisfied: scipy>=1.10.0 in /Users/jameshoyu/.pyenv/versions/3.11.9/lib/python3.11/site-packages (from scikit-learn) (1.16.3)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.8.0-cp311-cp311-macosx_12_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 41.1 MB/s eta 0:00:0000:0100:01
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 309.1/309.1 kB 24.8 MB/s eta 0:00:00
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 threadpoolctl-3.6.0
#
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
# Validation set
from sklearn.model_selection import train_test_split

train_scaled, val_scaled, train_target, val_target = train_test_split(train_input, train_target, test_size=0.2, random_state=42)

# %% [markdown]
# ## Train

# %%
# callbacks: save the best model 

checkpoint_cb = keras.callbacks.ModelCheckpoint('lenet5-model.keras', save_best_only=True)
early_stopping_cb = keras.callbacks.EarlyStopping(patience=2, restore_best_weights=True)

# %%
lenet5.compile(loss='sparse_categorical_crossentropy', metrics=['accuracy'])
hist = lenet5.fit(train_scaled, train_target, epochs=20, 
                  validation_data=(val_scaled, val_target),
                  callbacks=[checkpoint_cb, early_stopping_cb])
# Out:
# Epoch 1/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5897 - loss: 1.1024 - val_accuracy: 0.7257 - val_loss: 0.7084
# Epoch 2/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7462 - loss: 0.6574 - val_accuracy: 0.7698 - val_loss: 0.6062
# Epoch 3/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.7794 - loss: 0.5760 - val_accuracy: 0.7983 - val_loss: 0.5466
# Epoch 4/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8069 - loss: 0.5129 - val_accuracy: 0.8200 - val_loss: 0.4808
# Epoch 5/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8277 - loss: 0.4678 - val_accuracy: 0.8318 - val_loss: 0.4527
# Epoch 6/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8394 - loss: 0.4370 - val_accuracy: 0.8298 - val_loss: 0.4563
# Epoch 7/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8451 - loss: 0.4144 - val_accuracy: 0.8453 - val_loss: 0.4126
# Epoch 8/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8556 - loss: 0.3953 - val_accuracy: 0.8575 - val_loss: 0.3819
# Epoch 9/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8587 - loss: 0.3815 - val_accuracy: 0.8589 - val_loss: 0.3840
# Epoch 10/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8640 - loss: 0.3664 - val_accuracy: 0.8627 - val_loss: 0.3664
# Epoch 11/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8692 - loss: 0.3553 - val_accuracy: 0.8630 - val_loss: 0.3661
# Epoch 12/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8718 - loss: 0.3454 - val_accuracy: 0.8457 - val_loss: 0.4021
# Epoch 13/20
# 1500/1500 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.8740 - loss: 0.3363 - val_accuracy: 0.8587 - val_loss: 0.3758

# %%
epochs = range(1, len(hist.history['loss'])+1)

fig, axs = plt.subplots(1, 2, figsize=(12, 4))
axs[0].plot(epochs, hist.history['loss'])
axs[0].plot(epochs, hist.history['val_loss'])
axs[0].set_xticks(epochs)
axs[0].set_xlabel('epochs')
axs[0].set_ylabel('loss')
axs[1].plot(epochs, hist.history['accuracy'])
axs[1].plot(epochs, hist.history['val_accuracy'])
axs[1].set_xticks(epochs)
axs[1].set_xlabel('epochs')
axs[1].set_ylabel('accuracy')
plt.show()
